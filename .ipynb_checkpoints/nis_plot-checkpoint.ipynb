# %%
import matplotlib.pyplot as plt

# %%
# Plot Lidar NIS
error = []
with open("build/error.txt", "r") as file:
    error = file.read().splitlines()
error = list(map(float, error))


fig = plt.figure()
plt.plot(error)
plt.title("NIS (LIDAR)")
plt.xlabel("Measurement Index")
plt.ylabel("NIS")
plt.plot(threshold_laser)
plt.show()
fig.savefig('lidarNis.png')
